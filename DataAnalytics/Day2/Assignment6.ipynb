# %% [markdown]
# ## Q1

# %%
import pandas as pd
import numpy as np

from Assignment2 import subset

df = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})

print(df)

df.isna()
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# ## Q2

# %%
df.isna().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %% [markdown]
# ## Q3

# %%
df.isna().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# ## Q4

# %%
df2 = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, '--', 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, '?', 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': ['?', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, '--', 3001, 3001],
    'salesman_id': [5002.0, 5003.0, '?', 5001, np.nan, 5002.0, 5001.0, '?', 5003.0, 5002.0, 5003.0, '--']
})
print(df2)

df2.replace('--', np.nan, inplace=True)
df2.replace('?', np.nan, inplace=True)
df2
# Out:
#      ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001.0     150.5           ?        3002      5002.0
# 1       NaN    270.65  2012-09-10        3001      5003.0
# 2   70002.0     65.26         NaN        3001           ?
# 3   70004.0     110.5  2012-08-17        3003        5001
# 4       NaN     948.5  2012-09-10        3002         NaN
# 5   70005.0    2400.6  2012-07-27        3001      5002.0
# 6        --    5760.0  2012-09-10        3001      5001.0
# 7   70010.0         ?  2012-10-10        3004           ?
# 8   70003.0    2480.4  2012-10-10        3003      5003.0
# 9   70012.0    250.45  2012-06-27          --      5002.0
# 10      NaN     75.29  2012-08-17        3001      5003.0
# 11  70013.0    3045.6  2012-04-25        3001          --
# C:\Users\dai\AppData\Local\Temp\ipykernel_3616\3068213089.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.replace('--', np.nan, inplace=True)
# C:\Users\dai\AppData\Local\Temp\ipykernel_3616\3068213089.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.replace('?', np.nan, inplace=True)
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50         NaN       3002.0       5002.0
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0          NaN
# 3   70004.0     110.50  2012-08-17       3003.0       5001.0
# 4       NaN     948.50  2012-09-10       3002.0          NaN
# 5   70005.0    2400.60  2012-07-27       3001.0       5002.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0        NaN  2012-10-10       3004.0          NaN
# 8   70003.0    2480.40  2012-10-10       3003.0       5003.0
# 9   70012.0     250.45  2012-06-27          NaN       5002.0
# 10      NaN      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN

# %% [markdown]
# ## Q5

# %%
df_droprows = df.dropna()
df_droprows
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %% [markdown]
# ## Q6

# %%
df_dropcolumns = df.dropna(axis=1)
df_dropcolumns
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %% [markdown]
# ## Q7

# %%
df_new = pd.DataFrame({
    'ord_no': [np.nan, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [np.nan, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': [np.nan, '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [np.nan, 3001.0, 3001.0, 3003.0, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, 3001.0]
})

print(df_new)
df_new.dropna(how='all', inplace=True)
df_new
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %% [markdown]
# ## Q8

# %%
df3 = pd.DataFrame({
    'ord_no': [np.nan, np.nan, 70002.0, np.nan, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan],
    'purch_amt': [np.nan, 270.65, 65.26, np.nan, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, np.nan],
    'ord_date': [np.nan, '2012-09-10', np.nan, np.nan, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', np.nan],
    'customer_id': [np.nan, 3001.0, 3001.0, np.nan, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, np.nan]
})

print(df3)

df3.dropna(thresh=2, inplace=True)
df3
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0

# %% [markdown]
# ## Q9

# %%
df4 = pd.DataFrame({
    'ord_no': [np.nan, np.nan, 70002.0, np.nan, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan],
    'purch_amt': [np.nan, 270.65, 65.26, np.nan, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, np.nan],
    'ord_date': [np.nan, '2012-09-10', np.nan, np.nan, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', np.nan],
    'customer_id': [np.nan, 3001.0, 3001.0, np.nan, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, np.nan]
})

df4.dropna(subset=['ord_no','customer_id'])
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 2  70002.0      65.26         NaN       3001.0
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# ## Q10

# %%
df4.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# ## Q11

# %%
df4.isna().sum().sum()
# Out:
# np.int64(17)

# %% [markdown]
# ## Q12

# %%
df4.ord_no.fillna(value=0.0)
# Out:
# 0         0.0
# 1         0.0
# 2     70002.0
# 3         0.0
# 4         0.0
# 5     70005.0
# 6         0.0
# 7     70010.0
# 8     70003.0
# 9     70012.0
# 10        0.0
# 11        0.0
# Name: ord_no, dtype: float64

# %% [markdown]
# ## Q13

# %%
df4.fillna(method='pad')
# Out:
# C:\Users\dai\AppData\Local\Temp\ipykernel_3616\3972502562.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4.fillna(method='pad')
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26  2012-09-10       3001.0
# 3   70002.0      65.26  2012-09-10       3001.0
# 4   70002.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6   70005.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10  70012.0      75.29  2012-08-17       3001.0
# 11  70012.0      75.29  2012-08-17       3001.0

# %%
df4.fillna(method='bfill')
# Out:
# C:\Users\dai\AppData\Local\Temp\ipykernel_3616\4118119547.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4.fillna(method='bfill')
#      ord_no  purch_amt    ord_date  customer_id
# 0   70002.0     270.65  2012-09-10       3001.0
# 1   70002.0     270.65  2012-09-10       3001.0
# 2   70002.0      65.26  2012-09-10       3001.0
# 3   70005.0     948.50  2012-09-10       3002.0
# 4   70005.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6   70010.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN

# %% [markdown]
# ## Q14

# %%
df4.fillna(value = df.ord_no.mean())
# Out:
#       ord_no  purch_amt    ord_date  customer_id
# 0   70006.25   70006.25    70006.25     70006.25
# 1   70006.25     270.65  2012-09-10      3001.00
# 2   70002.00      65.26    70006.25      3001.00
# 3   70006.25   70006.25    70006.25     70006.25
# 4   70006.25     948.50  2012-09-10      3002.00
# 5   70005.00    2400.60  2012-07-27      3001.00
# 6   70006.25    5760.00  2012-09-10      3001.00
# 7   70010.00    1983.43  2012-10-10      3004.00
# 8   70003.00    2480.40  2012-10-10      3003.00
# 9   70012.00     250.45  2012-06-27      3002.00
# 10  70006.25      75.29  2012-08-17      3001.00
# 11  70006.25   70006.25    70006.25     70006.25

# %%
df4.fillna(value = df.ord_no.median())
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0   70004.5   70004.50     70004.5      70004.5
# 1   70004.5     270.65  2012-09-10       3001.0
# 2   70002.0      65.26     70004.5       3001.0
# 3   70004.5   70004.50     70004.5      70004.5
# 4   70004.5     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6   70004.5    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10  70004.5      75.29  2012-08-17       3001.0
# 11  70004.5   70004.50     70004.5      70004.5

# %% [markdown]
# ## Q15

# %%
df_inter = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})

df_inter['purch_amt'].interpolate(method='linear', direction = 'forward', inplace=True)
df_inter
# Out:
# C:\Users\dai\AppData\Local\Temp\ipykernel_3616\55925598.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_inter['purch_amt'].interpolate(method='linear', direction = 'forward', inplace=True)
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     107.88  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    3354.25  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    1116.94  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %% [markdown]
# ## 16. Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.

# %%
df_inter = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'sale_amt':[10.50,20.65,np.nan,11.50,98.50,np.nan,57.00,19.43,np.nan,25.45,75.29,35.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})

misscount=(df_inter.isnull()).sum()
print(misscount)
# Out:
# 14

# %% [markdown]
# ## 17. Write a Pandas program to count the missing values in a given DataFrame.

# %%
df_inter = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'sale_amt':[10.50,20.65,np.nan,11.50,98.50,np.nan,57.00,19.43,np.nan,25.45,75.29,35.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})

misscount=(df_inter.isnull()).sum().sum()
print(misscount)
# Out:
# 14

# %% [markdown]
# ## 18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.

# %%
df_inter = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'sale_amt':[10.50,20.65,np.nan,11.50,98.50,np.nan,57.00,19.43,np.nan,25.45,75.29,35.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})

missindex=df_inter['ord_no'].isnull().to_numpy().nonzero()
print(missindex)
# Out:
# (array([ 1,  4,  6, 10]),)

# %% [markdown]
# ## 19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.

# %%
df_inter = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'sale_amt':[10.50,20.65,np.nan,11.50,98.50,np.nan,57.00,19.43,np.nan,25.45,75.29,35.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})

fillmissingvalues=df.fillna(df.mode().iloc[0])
print(fillmissingvalues)
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70001.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26  2012-09-10         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70001.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5001.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001       5001.0

# %% [markdown]
# ## 20. Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df_inter = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'sale_amt':[10.50,20.65,np.nan,11.50,98.50,np.nan,57.00,19.43,np.nan,25.45,75.29,35.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})
plt.figure(figsize=(16,10))
sns.heatmap(df.isnull())
# Out:
# <Axes: >
