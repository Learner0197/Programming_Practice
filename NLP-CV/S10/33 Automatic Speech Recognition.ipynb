# %%
#pip install speechrecognition pyttsx3

# %% [markdown]
# ### TTS

# %%
import pyttsx3

# %%
engine=pyttsx3.init()

# %%
#Set the properties
engine.setProperty('rate',150)
engine.setProperty('volume',0.9)

# %%
text='Welcome to world of Deep Learning using Python Programming.'

# %%
# engine.say(text)
# engine.runAndWait()

# %%
pip install git+https://github.com/killjoy1221/playsound.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/killjoy1221/playsound.git to c:\users\dai\appdata\local\temp\pip-req-build-qwg3t7vr
#   Resolved https://github.com/killjoy1221/playsound.git to commit ebb6ee6f00a045c87187212b39f5a4c66384554c
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=6953 sha256=0b1cff773ae59179213745d8abe7231bfcd7462ed228c30b025cf25e64eba637
#   Stored in directory: C:\Users\dai\AppData\Local\Temp\pip-ephem-wheel-cache-won_vk0h\wheels\61\32\0b\26eacb096a5491d4808e2d5d9b04d7bcc6b7aee0506dba4313
# Successfully built playsound
# ...

# %% [markdown]
# ### ASR

# %%
import speech_recognition as sr

# %%
r=sr.Recognizer()

# %%
with sr.Microphone() as source:
    r.adjust_for_ambient_noise(source)
    print('Speak:')
    audio=r.listen(source)
    print('You said:',r.recognize_google(audio))
# Out:
# Speak:
# You said: hello hello hello hello

# %%
#pip install gtts playsound

# %%
from gtts import gTTS
from playsound import playsound

# %%
tts=gTTS(text='Welcome to the world of Deep Learning using Python',lang='en')

# %%
tts.save('audio.mp3')
playsound('audio.mp3')

# %%
tts=gTTS(text='अमरिका क्या कहता था ? क्या हो तुम? आज हम पूछते है तू क्या है बे?',lang='hi')

# %%
tts.save('audio2.mp3')
playsound('audio2.mp3')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 tts.save('audio2.mp3')
# ----> 2 playsound('audio2.mp3')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\playsound.py:56, in _playsoundWin(sound, block)
#      54     logger.debug('Starting')
#      55     winCommand(u'open {}'.format(sound))
# ---> 56     winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#      57     logger.debug('Returning')
#      58 finally:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\playsound.py:42, in _playsoundWin.<locals>.winCommand(*command)
#      40 buf = create_unicode_buffer(bufLen)
#      41 command = ' '.join(command)
# ---> 42 errorCode = int(windll.winmm.mciSendStringW(command, buf, bufLen - 1, 0))  # use widestring version of the function
#      43 if errorCode:
#      44     errorBuffer = create_unicode_buffer(bufLen)
#
# ...
