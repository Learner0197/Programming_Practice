# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
arr1 = np.arange(400, 600, 20)
np.random.shuffle(arr1)
arr2 = np.linspace(0, 10, 10)
np.random.shuffle(arr2)
arr3 = np.linspace(0, 1, 10)
np.random.shuffle(arr3)

arr = np.array([arr1, arr2, arr3])
arr
# Out:
# array([[5.00000000e+02, 4.40000000e+02, 4.60000000e+02, 5.20000000e+02,
#         4.20000000e+02, 5.80000000e+02, 5.60000000e+02, 5.40000000e+02,
#         4.00000000e+02, 4.80000000e+02],
#        [8.88888889e+00, 1.11111111e+00, 2.22222222e+00, 0.00000000e+00,
#         1.00000000e+01, 4.44444444e+00, 7.77777778e+00, 6.66666667e+00,
#         5.55555556e+00, 3.33333333e+00],
#        [2.22222222e-01, 6.66666667e-01, 3.33333333e-01, 1.11111111e-01,
#         8.88888889e-01, 5.55555556e-01, 4.44444444e-01, 7.77777778e-01,
#         1.00000000e+00, 0.00000000e+00]])

# %%
df = pd.DataFrame(arr)
df = df.transpose().rename({0:"X1", 1:"X2", 2:"X3"}, axis=1)
df
# Out:
#       X1         X2        X3
# 0  500.0   8.888889  0.222222
# 1  440.0   1.111111  0.666667
# 2  460.0   2.222222  0.333333
# 3  520.0   0.000000  0.111111
# 4  420.0  10.000000  0.888889
# 5  580.0   4.444444  0.555556
# 6  560.0   7.777778  0.444444
# 7  540.0   6.666667  0.777778
# 8  400.0   5.555556  1.000000
# 9  480.0   3.333333  0.000000

# %%
ss = StandardScaler().set_output(transform="pandas")
ss.fit(df)
df1 = ss.transform(df)
df1
# Out:
#          X1        X2        X3
# 0  0.174078  1.218544 -0.870388
# 1 -0.870388 -1.218544  0.522233
# 2 -0.522233 -0.870388 -0.522233
# 3  0.522233 -1.566699 -1.218544
# 4 -1.218544  1.566699  1.218544
# 5  1.566699 -0.174078  0.174078
# 6  1.218544  0.870388 -0.174078
# 7  0.870388  0.522233  0.870388
# 8 -1.566699  0.174078  1.566699
# 9 -0.174078 -0.522233 -1.566699

# %%
df1.describe().loc[["mean", "std"],:]
# Out:
#                 X1            X2            X3
# mean  1.665335e-17 -1.998401e-16 -8.881784e-17
# std   1.054093e+00  1.054093e+00  1.054093e+00

# %%
mm = MinMaxScaler().set_output(transform="pandas")
mm.fit(df)
df2 = mm.transform(df)
df2
# Out:
#          X1        X2        X3
# 0  0.555556  0.888889  0.222222
# 1  0.222222  0.111111  0.666667
# 2  0.333333  0.222222  0.333333
# 3  0.666667  0.000000  0.111111
# 4  0.111111  1.000000  0.888889
# 5  1.000000  0.444444  0.555556
# 6  0.888889  0.777778  0.444444
# 7  0.777778  0.666667  0.777778
# 8  0.000000  0.555556  1.000000
# 9  0.444444  0.333333  0.000000

# %%
df2.describe().loc[["mean", "std"],:]
# Out:
#             X1        X2        X3
# mean  0.500000  0.500000  0.500000
# std   0.336406  0.336406  0.336406
