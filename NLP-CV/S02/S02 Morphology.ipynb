# %%
from polyglot.text import Word

nwords = ['तुमच्या', 'अँड्रॉइड', 'िव्हाइसवर']

for word in mwords:
    w = Word(word, language='mr')
    print(word, '\t\t', w.morphemes)

# %%
from polyglot.text import Text
data = 'wewillmeettoday'
t = Text(data)
t.morphemes
