# %%
import pickle
import pandas as pd

# %% [markdown]
# # Deserialization

# %%
infile = open(r"C:\Users\dai\Downloads\Cases\Concrete_Strength\rf_conc_311.pkl", "rb")
objLoad = pickle.load(infile)
infile.close()

# %%
tst = pd.read_csv(r'C:\Users\dai\PycharmProjects\ML\Linear_Reg\testConcrete.csv')
objLoad.predict(tst)
# Out:
# array([63.4894    , 40.6652    , 36.4088    , 43.2591    , 59.89651167,
#        30.3139    , 50.965     , 61.06578667, 53.7163    , 48.1584    ,
#        47.962     , 50.0491    , 49.4003    , 37.1643    ])
