# %% [markdown]
# ## 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import lineStyles

x = range(1, 50)
y = [i * 3 for i in x]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Line Graph')
plt.show()

# %% [markdown]
# ## 2. Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title.

# %%
x = [1,2,3]
y = [2,4,1]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Line graph 2')
plt.show()

# %% [markdown]
# ## 3. Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title.

# %%
with open("test.txt") as f:
    data = f.read()
data = data.split('\n')
x = [int(row.split(' ')[0]) for row in data]
y = [int(row.split(' ')[1]) for row in data]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Line graph 3')
plt.show()

# %% [markdown]
# ## 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.

# %%
import seaborn as sns
# df = pd.read_csv("fdata.csv")
df = pd.read_csv('fdata.csv', index_col=0)
# df.plot()
# plt.show()
df.plot()
plt.show()

# %% [markdown]
# ## 5. Write a Python program to plot two or more lines on same plot with suitable legends of each line.

# %%
x = [1,2,3]
y1 = [2,4,1]
y2 = [4,2,3]
plt.plot(x, y1)
plt.plot(x, y2)
plt.legend(['y1', 'y2'])
plt.show()

# %% [markdown]
# ## 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
x = [1,2,3]
y1 = [2,4,1]
y2 = [4,2,3]
plt.plot(x, y1, linewidth=8, color='yellow')
plt.plot(x, y2, linewidth=4, color='purple')
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.show()

# %% [markdown]
# ## 7. Write a Python program to plot two or more lines with different styles.

# %%
x = [1,2,3]
y1 = [2,4,1]
y2 = [4,2,3]
plt.plot(x, y1, linewidth=6, color='yellow', linestyle='dashed')
plt.plot(x, y2, linewidth=4, color='purple', linestyle='dashdot')
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.show()

# %% [markdown]
# ## 8. Write a Python program to plot two or more lines and set the line markers.

# %%
x = [1,2,3]
y1 = [2,4,1]
y2 = [4,2,3]
plt.plot(x, y1, linewidth=4, color='yellow', linestyle='dashed', marker='o', markersize=10)
plt.plot(x, y2, linewidth=4, color='purple', linestyle='dashdot', marker='x', markersize=10)
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.show()

# %% [markdown]
# ## 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
x = [1,2,3]
y1 = [2,4,1]
y2 = [4,2,3]
plt.plot(x, y1, linewidth=4, color='yellow', linestyle='dashed', marker='o', markersize=10)
plt.plot(x, y2, linewidth=4, color='purple', linestyle='dashdot', marker='x', markersize=10)
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])
plt.legend(['y1', 'y2'])

plt.axis()
plt.axis([0,6,0,40])
plt.show()

# %% [markdown]
# ## 10. Write a Python program to plot quantities which have an x and y position.

# %%
# np.random.seed(42)

# x = np.random.randint(0,11, size=10)
# y = np.random.randint(0,11, size=10)
#
# plt.scatter(x,y)
# plt.show()

x=np.arange(0,11,2)
y=np.arange(0,30,5)
z=np.arange(0,11,2)

# print(x)
# print(y)
plt.scatter(x,y)
plt.scatter(x,z,color='yellow')
plt.show()

# %% [markdown]
# ## 11. Write a Python program to plot several lines with different format styles in one command using arrays.

# %%
x=pd.Series([1,3,5,7,9])
y=pd.Series([2,4,6,8,0])
z=pd.Series([24,45,54,55,15])
a=pd.Series([1,25,3,42,53])
plt.plot(x,y,linestyle='dashed')
plt.plot(x,z,linestyle='dotted')
plt.plot(x,a,linestyle='dashdot')

# %% [markdown]
# ## 12. Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.

# %%
df_new = pd.read_csv('fdata.csv')
df_new.plot(x='Date', y='Close')
plt.show()

# %% [markdown]
# ## 13. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with linestyle -, width .5. and color blue.

# %%
df_new = pd.read_csv('fdata.csv')
df_new.plot(x='Date', y='Close', linewidth=2)
plt.grid(True, linestyle= '--', linewidth=0.5, color='blue')
plt.show()

# %% [markdown]
# ## 14. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn off ticks.

# %%
df_new = pd.read_csv('fdata.csv')
df_new.plot(x='Date', y='Close', linewidth=2)

plt.minorticks_on()  # Enable minor ticks

plt.grid(which='major', linestyle='-', linewidth=0.5, color='red')
plt.grid(which='minor', linestyle=':', linewidth=0.5, color='black')

# Turn off tick marks but keep tick labels
plt.tick_params(which='both', top=False, left=False, right=False, bottom=False,
                labelleft=True, labelbottom=True)

plt.show()

# %% [markdown]
# ## 15. Write a Python program to create multiple plots.

# %%
fig = plt.figure(figsize=(10,6))
plt.subplot2grid((2,3), (0,0), colspan=3)
plt.subplot2grid((2,3), (1,0))
plt.subplot2grid((2,3), (1,1))
plt.subplot2grid((2,3), (1,2))
plt.show()
