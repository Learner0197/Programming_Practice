# %%
import re
import string

import nltk
from nltk import sent_tokenize

# %%
nltk.download('punkt') #tokenizer
nltk.download('punkt_tab') #tokenization
nltk.download('aberaged_perceptron_tagger') #POS Tagging
nltk.download('aberaged_perceptron_tagger_eng') #POS tagging for english
nltk.download('wordnet') #Wordnet Vocabulary
nltk.download('stopwords') #Stopwords vocabulary
nltk.download('omw-1.8') #stemming and lemmatization
nltk.download('indian') #Indian language POS tagging
nltk.download('maxent_ne_chunker') #NER Chunking
nltk.download('maxent_ne_chunker_tab') #NER Chunking
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Error loading aberaged_perceptron_tagger: Package
# [nltk_data]     'aberaged_perceptron_tagger' not found in index
# [nltk_data] Error loading aberaged_perceptron_tagger_eng: Package
# [nltk_data]     'aberaged_perceptron_tagger_eng' not found in index
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading omw-1.8: Package 'omw-1.8' not found in
# [nltk_data]     index
# [nltk_data] Downloading package indian to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\dai\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
sent = 'They told that their ages are 26 31 and 29 respectively.'

# %%
# # Write a program to find the average of ages mentioned in the sentence:
# sm=0
# l=[]
# for s in range(len(sent)):
#     if sent[s].isdigit() and sent[s+1].:
#         sm = sm + ((int(sent[s]) * 10) + int(sent[s+1])

# %%
avg = 0
sm = 0
l= sent.split()
l1=[]
for i in l:
    if i.isnumeric():
        l1.append(i)
        sm += int(i)
avg = sm / len(l1)
print(avg)
# Out:
# 28.666666666666668

# %%
num = [int(word) for word in sent.split() if word.isdigit()]
num
# Out:
# [26, 31, 29]

# %%
sum(num)/len(num)
# Out:
# 28.666666666666668

# %% [markdown]
# ## Word Tokenizer

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(sent)

# %%
tokens
# Out:
# ['They',
#  'told',
#  'that',
#  'their',
#  'ages',
#  'are',
#  '26',
#  '31',
#  'and',
#  '29',
#  'respectively',
#  '.']

# %%
sents = 'Hello friends! How are you? Welcome to Python Programming.'

# %%
word_tokenize(sents)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'Python',
#  'Programming',
#  '.']

# %%
sent1 = 'Dr. Deshmukh told Mrs. Sunita to take rest.'

# %%
word_tokenize(sent1)
# Out:
# ['Dr.', 'Deshmukh', 'told', 'Mrs.', 'Sunita', 'to', 'take', 'rest', '.']

# %% [markdown]
# ## Sentence Tokenizer

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(sents)
# Out:
# ['Hello friends!', 'How are you?', 'Welcome to Python Programming.']

# %%
# Find percentages of punctuations present in this sentence.

p = []
for i in word_tokenize(sents):
    if not i.isalnum():
        p.append(i)
prcnt = (len(p)/len(word_tokenize(sents)))*100
print(prcnt)
# Out:
# 25.0

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
p = []
for i in word_tokenize(sent1):
    if not i.isalnum():
        p.append(i)
prcnt = (len(p)/len(word_tokenize(sent1)))*100
print(prcnt)
# Out:
# 33.33333333333333

# %%
p = []
for i in word_tokenize(sents):
    if i in string.punctuation:
        p.append(i)
prcnt = (len(p)/len(word_tokenize(sents)))*100
print(prcnt)
# Out:
# 25.0

# %%
text = '''पुणे भारतके महाराष्ट्र राज्यकs एक महत्त्वपूर्ण शहर छी। यी शहर महाराष्ट्रके पश्चिम भाग, मुला आ मूठा इ दुनु नदिसभके किनार बसल अछि आर पुणे जिलाक प्रशासकीय मुख्यालय छी। पुणे भारतक छठम सबसं बड़का शहर आ महाराष्ट्र कs दोसर सबसं बड़का शहर छी। सार्वजनिक सुखसुविधा आ विकासके हिसाबसं पुणे महाराष्ट्रमे मुम्बईके बाद अग्रसर छै। अनेक नामांकित शिक्षणसंस्थासभ होइके कारण इ शहरक 'पूरब कs ऑक्सफोर्ड' सहो कहल जाइत अछि। पुणेमें अनेक प्रौद्योगिकी आर ऑटोमोबाईल उपक्रम अछि, अही कारन पुणे भारतक ”डेट्राइट” जकाँ लागैत अछि। काफी प्राचीन ज्ञात इतिहाससं पुणे शहर महाराष्ट्र कs 'सांस्कृतिक राजधानी' मानल जाइत छै। मराठी भाषा इ शहरक मुख्य भाषा छी।



नाम
पुणे यह नाम 'पुण्यनगरी' नामसं आएल समझल जाइत छै । इ शहर ई.स. ८ के शतकमे 'पुन्नक' (या 'पुण्यक') नामसं जानल जाइत छल, एहन सन्दर्भ मिलैत अछि। ई.स. ११के शतकमे 'कसबे पुणे' आ 'पुनवडी' नामसं जानल जाई लागल। मराठा साम्राज्यके काल खण्डमे शहरकs नाम 'पुणे'के रूपमे उपयोगमे लाबलक । ब्रिटिशसभ एकरा 'पूना' कहि कs संबोधित करsक सुरुआत केलक। आब इ पुणे, अही आधिकारिक नामसं जानल जाइत अछि।



इतिहास
आठहम शताब्दीमे पुणे कs पुन्नक नामसं जानल जाइत छल। शहरक सबसं पुरना वर्णनइ.स. ७५८क छै, जब उ कालके राष्ट्रकूट राजमे एकर उल्लेख मिलैत अछि । मध्ययुग कालक एक प्रमाण जंगली महाराज मार्ग पर पाओल जाइ वला पातालेश्वर गुफा अछि, जे आठ्हम सदी कs मानल जाइत अछि।'''

# %%
text
# Out:
# "पुणे भारतके महाराष्ट्र राज्यकs एक महत्त्वपूर्ण शहर छी। यी शहर महाराष्ट्रके पश्चिम भाग, मुला आ मूठा इ दुनु नदिसभके किनार बसल अछि आर पुणे जिलाक प्रशासकीय मुख्यालय छी। पुणे भारतक छठम सबसं बड़का शहर आ महाराष्ट्र कs दोसर सबसं बड़का शहर छी। सार्वजनिक सुखसुविधा आ विकासके हिसाबसं पुणे महाराष्ट्रमे मुम्बईके बाद अग्रसर छै। अनेक नामांकित शिक्षणसंस्थासभ होइके कारण इ शहरक 'पूरब कs ऑक्सफोर्ड' सहो कहल जाइत अछि। पुणेमें अनेक प्रौद्योगिकी आर ऑटोमोबाईल उपक्रम अछि, अही कारन पुणे भारतक ”डेट्राइट” जकाँ लागैत अछि। काफी प्राचीन ज्ञात इतिहाससं पुणे शहर महाराष्ट्र कs 'सांस्कृतिक राजधानी' मानल जाइत छै। मराठी भाषा इ शहरक मुख्य भाषा छी।\n\n\n\nनाम\nपुणे यह नाम 'पुण्यनगरी' नामसं आएल समझल जाइत छै । इ शहर ई.स. ८ के शतकमे 'पुन्नक' (या 'पुण्यक') नामसं जानल जाइत छल, एहन सन्दर्भ मिलैत अछि। ई.स. ११के शतकमे 'कसबे पुणे' आ 'पुनवडी' नामसं जानल जाई लागल। मराठा साम्राज्यके काल खण्डमे शहरकs नाम 'पुणे'के रूपमे उपयोगमे लाबलक । ब्रिटिशसभ एकरा 'पूना' कहि कs संबोधित करsक सुरुआत केलक। आब इ पुणे, अही आधिकारिक नामसं जानल जाइत अछि।\n\n\n\nइतिहास\nआठहम शताब्दीमे पुणे कs पुन्नक नामसं जानल जाइत छल। शहरक सबसं पुरना वर्णनइ.स. ७५८क छै, जब उ कालके राष्ट्रकूट राजमे एकर उल्लेख मिलैत अछि । मध्ययुग कालक एक प्रमाण जंगली महाराज मार्ग पर पाओल जाइ वला पातालेश्वर गुफा अछि, जे आठ्हम सदी कs मानल जाइत अछि।"

# %%
word_tokenize(text)
# Out:
# ['पुणे',
#  'भारतके',
#  'महाराष्ट्र',
#  'राज्यकs',
#  'एक',
#  'महत्त्वपूर्ण',
#  'शहर',
#  'छी।',
#  'यी',
#  'शहर',
#  'महाराष्ट्रके',
#  'पश्चिम',
#  'भाग',
#  ',',
#  'मुला',
#  'आ',
#  'मूठा',
#  'इ',
#  'दुनु',
#  'नदिसभके',
#  'किनार',
#  'बसल',
#  'अछि',
#  'आर',
#  'पुणे',
#  'जिलाक',
#  'प्रशासकीय',
#  'मुख्यालय',
#  'छी।',
#  'पुणे',
#  'भारतक',
#  'छठम',
#  'सबसं',
#  'बड़का',
#  'शहर',
#  'आ',
#  'महाराष्ट्र',
#  'कs',
#  'दोसर',
#  'सबसं',
#  'बड़का',
#  'शहर',
#  'छी।',
#  'सार्वजनिक',
#  'सुखसुविधा',
#  'आ',
#  'विकासके',
#  'हिसाबसं',
#  'पुणे',
#  'महाराष्ट्रमे',
#  'मुम्बईके',
#  'बाद',
#  'अग्रसर',
#  'छै।',
#  'अनेक',
#  'नामांकित',
#  'शिक्षणसंस्थासभ',
#  'होइके',
#  'कारण',
#  'इ',
#  'शहरक',
#  "'",
#  'पूरब',
#  'कs',
#  'ऑक्सफोर्ड',
#  "'",
#  'सहो',
#  'कहल',
#  'जाइत',
#  'अछि।',
#  'पुणेमें',
#  'अनेक',
#  'प्रौद्योगिकी',
#  'आर',
#  'ऑटोमोबाईल',
#  'उपक्रम',
#  'अछि',
#  ',',
#  'अही',
#  'कारन',
#  'पुणे',
#  'भारतक',
#  '”',
#  'डेट्राइट',
#  '”',
#  'जकाँ',
#  'लागैत',
#  'अछि।',
#  'काफी',
#  'प्राचीन',
#  'ज्ञात',
#  'इतिहाससं',
#  'पुणे',
#  'शहर',
#  'महाराष्ट्र',
#  'कs',
#  "'",
#  'सांस्कृतिक',
#  'राजधानी',
#  "'",
#  'मानल',
#  'जाइत',
#  'छै।',
#  'मराठी',
#  'भाषा',
#  'इ',
#  'शहरक',
#  'मुख्य',
#  'भाषा',
#  'छी।',
#  'नाम',
#  'पुणे',
#  'यह',
#  'नाम',
#  "'",
#  'पुण्यनगरी',
#  "'",
#  'नामसं',
#  'आएल',
#  'समझल',
#  'जाइत',
#  'छै',
#  '।',
#  'इ',
#  'शहर',
#  'ई.स',
#  '.',
#  '८',
#  'के',
#  'शतकमे',
#  "'",
#  'पुन्नक',
#  "'",
#  '(',
#  'या',
#  "'",
#  'पुण्यक',
#  "'",
#  ')',
#  'नामसं',
#  'जानल',
#  'जाइत',
#  'छल',
#  ',',
#  'एहन',
#  'सन्दर्भ',
#  'मिलैत',
#  'अछि।',
#  'ई.स',
#  '.',
#  '११के',
#  'शतकमे',
#  "'कसबे",
#  'पुणे',
#  "'",
#  'आ',
#  "'",
#  'पुनवडी',
#  "'",
#  'नामसं',
#  'जानल',
#  'जाई',
#  'लागल।',
#  'मराठा',
#  'साम्राज्यके',
#  'काल',
#  'खण्डमे',
#  'शहरकs',
#  'नाम',
#  "'",
#  'पुणे',
#  "'",
#  'के',
#  'रूपमे',
#  'उपयोगमे',
#  'लाबलक',
#  '।',
#  'ब्रिटिशसभ',
#  'एकरा',
#  "'",
#  'पूना',
#  "'",
#  'कहि',
#  'कs',
#  'संबोधित',
#  'करsक',
#  'सुरुआत',
#  'केलक।',
#  'आब',
#  'इ',
#  'पुणे',
#  ',',
#  'अही',
#  'आधिकारिक',
#  'नामसं',
#  'जानल',
#  'जाइत',
#  'अछि।',
#  'इतिहास',
#  'आठहम',
#  'शताब्दीमे',
#  'पुणे',
#  'कs',
#  'पुन्नक',
#  'नामसं',
#  'जानल',
#  'जाइत',
#  'छल।',
#  'शहरक',
#  'सबसं',
#  'पुरना',
#  'वर्णनइ.स',
#  '.',
#  '७५८क',
#  'छै',
#  ',',
#  'जब',
#  'उ',
#  'कालके',
#  'राष्ट्रकूट',
#  'राजमे',
#  'एकर',
#  'उल्लेख',
#  'मिलैत',
#  'अछि',
#  '।',
#  'मध्ययुग',
#  'कालक',
#  'एक',
#  'प्रमाण',
#  'जंगली',
#  'महाराज',
#  'मार्ग',
#  'पर',
#  'पाओल',
#  'जाइ',
#  'वला',
#  'पातालेश्वर',
#  'गुफा',
#  'अछि',
#  ',',
#  'जे',
#  'आठ्हम',
#  'सदी',
#  'कs',
#  'मानल',
#  'जाइत',
#  'अछि।']

# %%
sent_tokenize(text) #tokenization doesn't happen properly because the sentences are ending with '|' and not with '.'
# Out:
# ["पुणे भारतके महाराष्ट्र राज्यकs एक महत्त्वपूर्ण शहर छी। यी शहर महाराष्ट्रके पश्चिम भाग, मुला आ मूठा इ दुनु नदिसभके किनार बसल अछि आर पुणे जिलाक प्रशासकीय मुख्यालय छी। पुणे भारतक छठम सबसं बड़का शहर आ महाराष्ट्र कs दोसर सबसं बड़का शहर छी। सार्वजनिक सुखसुविधा आ विकासके हिसाबसं पुणे महाराष्ट्रमे मुम्बईके बाद अग्रसर छै। अनेक नामांकित शिक्षणसंस्थासभ होइके कारण इ शहरक 'पूरब कs ऑक्सफोर्ड' सहो कहल जाइत अछि। पुणेमें अनेक प्रौद्योगिकी आर ऑटोमोबाईल उपक्रम अछि, अही कारन पुणे भारतक ”डेट्राइट” जकाँ लागैत अछि। काफी प्राचीन ज्ञात इतिहाससं पुणे शहर महाराष्ट्र कs 'सांस्कृतिक राजधानी' मानल जाइत छै। मराठी भाषा इ शहरक मुख्य भाषा छी।\n\n\n\nनाम\nपुणे यह नाम 'पुण्यनगरी' नामसं आएल समझल जाइत छै । इ शहर ई.स.",
#  "८ के शतकमे 'पुन्नक' (या 'पुण्यक') नामसं जानल जाइत छल, एहन सन्दर्भ मिलैत अछि। ई.स.",
#  "११के शतकमे 'कसबे पुणे' आ 'पुनवडी' नामसं जानल जाई लागल। मराठा साम्राज्यके काल खण्डमे शहरकs नाम 'पुणे'के रूपमे उपयोगमे लाबलक । ब्रिटिशसभ एकरा 'पूना' कहि कs संबोधित करsक सुरुआत केलक। आब इ पुणे, अही आधिकारिक नामसं जानल जाइत अछि।\n\n\n\nइतिहास\nआठहम शताब्दीमे पुणे कs पुन्नक नामसं जानल जाइत छल। शहरक सबसं पुरना वर्णनइ.स.",
#  '७५८क छै, जब उ कालके राष्ट्रकूट राजमे एकर उल्लेख मिलैत अछि । मध्ययुग कालक एक प्रमाण जंगली महाराज मार्ग पर पाओल जाइ वला पातालेश्वर गुफा अछि, जे आठ्हम सदी कs मानल जाइत अछि।']

# %%
ntext = """Pune (Marathi: Puṇē, pronounced [ˈpuɳe] ⓘ POO-nay), previously spelled in English as Poona (the official name until 1978),[15][16] is a city in the state of Maharashtra in the Deccan Plateau in Western India. It is the administrative headquarters of the Pune district, and of Pune division. In terms of the total amount of land under its jurisdiction, Pune is the largest city in Maharashtra by area, with a geographical area of 516.18 km2,[17] though by population it comes in a distant second to Mumbai. According to the 2011 Census of India, Pune has 7.2 million residents in the metropolitan region, making it the seventh-most populous metropolitan area in India.[18] The city of Pune is part of Pune Metropolitan Region.[19] Pune is one of the largest IT hubs in India.[20][21] It is also one of the most important automobile and manufacturing hubs of India. Pune is often referred to as the "Oxford of the East" because of its educational institutions.[22][23][24] It has been ranked "the most liveable city in India" several times.[25][26]

Pune at different points in time has been ruled by the Rashtrakuta dynasty, Ahmadnagar Sultanate, the Mughals, and the Adil Shahi dynasty. In the 18th century, the city was part of the Maratha Empire, and the seat of the Peshwas, the prime ministers of the Maratha Empire.[27] Pune was seized by the British East India Company in the Third Anglo-Maratha War; it gained municipal status in 1858, the year in which Crown rule began. Many historical landmarks like Shaniwarwada, Shinde Chhatri, and Vishrambaug Wada date to this era. Historical sites from different eras dot the city.

Pune has historically been a major cultural centre, with important figures like Dnyaneshwar, Shivaji, Tukaram, Baji Rao I, Balaji Baji Rao, Madhavrao I, Nana Fadnavis, Mahadev Govind Ranade, Gopal Krishna Gokhale, Mahatma Jyotirao Phule, Savitribai Phule, Gopal Ganesh Agarkar, Tarabai Shinde, Dhondo Keshav Karve, and Pandita Ramabai doing their life's work in Pune City or in an area that falls in Pune Metropolitan Region. Pune was a major centre of resistance to British Raj, with people like Gopal Krishna Gokhale, Bal Gangadhar Tilak playing leading roles in struggle for Indian independence in their times."""

# %%
c = []
for i in word_tokenize(ntext):
    if i.lower() == 'the':
        c.append(i)
len(c)
# Out:
# 30

# %%
ntext.count('the') + ntext.count('The') #will also count the 'the' which is a part of any other word.
# Out:
# 32

# %%
word_tokenize(ntext).count('the') + word_tokenize(ntext).count('The')
# Out:
# 30

# %%
from nltk import WordPunctTokenizer

# %%
tk = WordPunctTokenizer()

# %%
tk.tokenize(sents)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'Python',
#  'Programming',
#  '.']

# %% [markdown]
# ## Space Tokenizer

# %%
from nltk.tokenize import SpaceTokenizer

# %%
tk = SpaceTokenizer()

# %%
tk.tokenize(sents)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'Python',
#  'Programming.']

# %% [markdown]
# ## Tab Tokenizer

# %%
from nltk import TabTokenizer

# %%
tk = TabTokenizer()

# %%
sents = 'Hello friends! How are\tyou?\nWelcome to Python\tProgramming.'

# %%
print(sents)
# Out:
# Hello friends! How are	you?
# Welcome to Python	Programming.

# %%
tk.tokenize(sents)
# Out:
# ['Hello friends! How are', 'you?\nWelcome to Python', 'Programming.']

# %% [markdown]
# ## Line Tokenizer

# %%
from nltk.tokenize import LineTokenizer

# %%
tk = LineTokenizer()

# %%
tk.tokenize(sents)
# Out:
# ['Hello friends! How are\tyou?', 'Welcome to Python\tProgramming.']

# %% [markdown]
# ## Whitespace Tokenizer

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
tk = WhitespaceTokenizer()

# %%
tk.tokenize(sents)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'Python',
#  'Programming.']

# %% [markdown]
# ## Multi-Word Expression Tokenizer

# %%
nsent = "Chhatrapati Shivaji Maharaj was founder of Maratha Empire"

# %%
word_tokenize(nsent)
# Out:
# ['Chhatrapati',
#  'Shivaji',
#  'Maharaj',
#  'was',
#  'founder',
#  'of',
#  'Maratha',
#  'Empire']

# %%
from nltk.tokenize import MWETokenizer

# %%
tk = MWETokenizer(separator=' ')

# %%
tk.add_mwe(('Chhatrapati', 'Shivaji'))

# %%
tk.tokenize(word_tokenize(nsent))
# Out:
# ['Chhatrapati Shivaji', 'Maharaj', 'was', 'founder', 'of', 'Maratha', 'Empire']

# %% [markdown]
# ## Tweet Tokenizer

# %%
data = 'Hello friends!:) How are you? Welcome to Python <3Programming.'

# %%
from nltk.tokenize import TweetTokenizer

# %%
tk = TweetTokenizer()

# %%
tk.tokenize(data)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  ':)',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'Python',
#  '<3',
#  'Programming',
#  '.']

# %%
data = 'Hello friends👋 How are you?🤷Welcome to 🌎Python Programming.💻'

# %%
word_tokenize(data)
# Out:
# ['Hello',
#  'friends👋',
#  'How',
#  'are',
#  'you',
#  '?',
#  '🤷Welcome',
#  'to',
#  '🌎Python',
#  'Programming.💻']

# %%
tk.tokenize(data)
# Out:
# ['Hello',
#  'friends',
#  '👋',
#  'How',
#  'are',
#  'you',
#  '?',
#  '🤷',
#  'Welcome',
#  'to',
#  '🌎',
#  'Python',
#  'Programming',
#  '.',
#  '💻']

# %%
emojis = []
for i in tk.tokenize(data):
    if not i.isalnum() and i not in string.punctuation:
        emojis.append(i)
emojis
# Out:
# ['👋', '🤷', '🌎', '💻']

# %% [markdown]
# ## Custom Tokenizer

# %%
import re

# %%
def custom_tokenizer(text):
    return re.split(r"[.,;?!\s]+", text)

text = "This is some text with punctuation > Let's tokenize it. Is it ok?"

# %%
custom_tokenizer(text)
# Out:
# ['This',
#  'is',
#  'some',
#  'text',
#  'with',
#  'punctuation',
#  '>',
#  "Let's",
#  'tokenize',
#  'it',
#  'Is',
#  'it',
#  'ok',
#  '']
