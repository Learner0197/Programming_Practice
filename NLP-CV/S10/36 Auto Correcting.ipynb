# %%
from textblob import TextBlob

# %%
word='camputar'

# %%
blob=TextBlob(word)

# %%
blob.correct()
# Out:
# TextBlob("computer")

# %%
word = 'Komputar'
blob = TextBlob(word)
blob.correct()
# Out:
# TextBlob("Computer")

# %%
sent='It was a great dau. when they played on the grounf.'
blob = TextBlob(sent)

# %%
blob.correct()
# Out:
# TextBlob("It was a great day. when they played on the ground.")

# %%
sent='It was a great day. When they played on the ground.'
blob = TextBlob(sent)

# %%
blob.word_counts
# Out:
# defaultdict(int,
#             {'it': 1,
#              'was': 1,
#              'a': 1,
#              'great': 1,
#              'day': 1,
#              'when': 1,
#              'they': 1,
#              'played': 1,
#              'on': 1,
#              'the': 1,
#              'ground': 1})

# %%
blob.pos_tags
# Out:
# [('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('day', 'NN'),
#  ('When', 'WRB'),
#  ('they', 'PRP'),
#  ('played', 'VBD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('ground', 'NN')]

# %%
blob.tokenize()
# Out:
# WordList(['It', 'was', 'a', 'great', 'day', '.', 'When', 'they', 'played', 'on', 'the', 'ground', '.'])

# %%
blob.sentences
# Out:
# [Sentence("It was a great day."), Sentence("When they played on the ground.")]
